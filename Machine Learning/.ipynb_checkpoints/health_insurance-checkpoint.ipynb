# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %config Completer.use_jedi = False

sns.set_style("whitegrid")

# %%
df  = pd.read_csv("../Datasets/insurance_lr.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.countplot(x=df['sex'], palette="plasma", edgecolor="black", lw=2);

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.histplot(x=df['age'], color="crimson", edgecolor="black", lw=2, alpha=0.90);

# %%
print("Difference between Male and Female population in the Dataset:", df['sex'].value_counts()[0]-df['sex'].value_counts()[-1])
# Out:
# Difference between Male and Female population in the Dataset: 14

# %%
round(df['age'].mean())
# Out:
# 39

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.histplot(x=df['bmi'], color="crimson", edgecolor="black", lw=2, alpha=0.90); # Normal Distribution

# %%
df['bmi'].mean()
# Out:
# 30.66339686098655

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.histplot(x=df['charges'], color="crimson", edgecolor="black", lw=2, alpha=0.90); # 100 - 10k

# %%
df['charges'].mean()
# Out:
# 13270.422265141257

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.boxenplot(y=df['bmi'], color="orangered"); # Clear the outliers

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.boxenplot(y=df['age'], color="orangered"); # No outliers

# %%
df.corrwith(df["charges"]).sort_values(ascending=False)[1:]
# Out:
# age         0.299008
# bmi         0.198341
# children    0.067998
# dtype: float64

# %%
df['sex'] = df['sex'].apply(lambda x: 1 if x.lower()=="female" else 0)
df['smoker'] = df['smoker'].apply(lambda x: 1 if x=="yes" else 0)
df = pd.concat([df, pd.get_dummies(df['region'])], axis=1)
df.drop("region", axis=1, inplace=True)

# %%
df.head() # All numeric
# Out:
#    age  sex     bmi  children  smoker      charges  northeast  northwest  \
# 0   19    1  27.900         0       1  16884.92400          0          0
# 1   18    0  33.770         1       0   1725.55230          0          0
# 2   28    0  33.000         3       0   4449.46200          0          0
# 3   33    0  22.705         0       0  21984.47061          0          1
# 4   32    0  28.880         0       0   3866.85520          0          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
df.corrwith(df["charges"]).sort_values(ascending=False)[1:]
# Out:
# smoker       0.787251
# age          0.299008
# bmi          0.198341
# southeast    0.073982
# children     0.067998
# northeast    0.006349
# northwest   -0.039905
# southwest   -0.043210
# sex         -0.057292
# dtype: float64

# %%
plt.figure(figsize=(12, 5), dpi=100)
df.corrwith(df["charges"]).sort_values(ascending=False)[1:].plot(kind="bar", color='crimson')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum() # SWEET
# Out:
# age          0
# sex          0
# bmi          0
# children     0
# smoker       0
# charges      0
# northeast    0
# northwest    0
# southeast    0
# southwest    0
# dtype: int64

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.scatterplot(x=df['charges'], y=df['age']) # some sort of postive corr
# Out:
# <AxesSubplot:xlabel='charges', ylabel='age'>

# %%
plt.figure(figsize=(12, 5), dpi=100)
sns.scatterplot(x=df['charges'], y=df['smoker']) # some sort of postive corr
# Out:
# <AxesSubplot:xlabel='charges', ylabel='smoker'>

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northeast  northwest  \
# 0   19    1  27.900         0       1  16884.92400          0          0
# 1   18    0  33.770         1       0   1725.55230          0          0
# 2   28    0  33.000         3       0   4449.46200          0          0
# 3   33    0  22.705         0       0  21984.47061          0          1
# 4   32    0  28.880         0       0   3866.85520          0          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
scaler = StandardScaler()
converter = PolynomialFeatures(degree=2, include_bias=False)

# %%
X, y = df.drop("charges", axis=1), df["charges"]

# %%
X = converter.fit_transform(X)

# %%
X.shape
# Out:
# (1338, 54)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Ridge()

# %%
params = {"alpha":[0.1, 0.5, 1, 3, 5, 10, 15, 20],
         "max_iter":[1000000],
         "normalize":[True, False],
         "fit_intercept":[True, False],
         "random_state":[42, 101]}

# %%
grid_search = GridSearchCV(model, params, scoring="explained_variance", cv=10, verbose=1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 0.5, 1, 3, 5, 10, 15, 20],
#                          'fit_intercept': [True, False], 'max_iter': [1000000],
#                          'normalize': [True, False],
#                          'random_state': [42, 101]},
#              scoring='explained_variance', verbose=1)

# %%
abs(grid_search.best_score_)
# Out:
# 0.8180998788303155

# %%
grid_search.best_estimator_
# Out:
# Ridge(alpha=1, max_iter=1000000, random_state=42)

# %%
model = Ridge(alpha=1, max_iter=1000000, random_state=42)

# %%
cv = cross_validate(model, X, y, scoring=["neg_mean_squared_error", "explained_variance"], cv=10)

# %%
cv_df = pd.DataFrame(cv)

# %%
cv_df
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  test_explained_variance
# 0  0.003990    0.001994                -2.349342e+07                 0.859879
# 1  0.002992    0.001000                -2.231451e+07                 0.844876
# 2  0.002993    0.000997                -2.374520e+07                 0.830665
# 3  0.001996    0.000995                -2.867690e+07                 0.759738
# 4  0.001992    0.000000                -2.248392e+07                 0.867372
# 5  0.005985    0.003992                -1.225209e+07                 0.906924
# 6  0.002970    0.000998                -2.183923e+07                 0.853653
# 7  0.001995    0.000996                -3.192373e+07                 0.783403
# 8  0.001991    0.000999                -2.086421e+07                 0.839086
# 9  0.003004    0.000986                -2.994702e+07                 0.829562

# %%
cv_df['test_mean_squared_error'] = abs((np.round(cv_df['test_neg_mean_squared_error'], 0)))

# %%
cv_df.drop("test_neg_mean_squared_error", axis=1, inplace=True)

# %%
cv_df
# Out:
#    fit_time  score_time  test_explained_variance  test_mean_squared_error
# 0  0.003990    0.001994                 0.859879               23493419.0
# 1  0.002992    0.001000                 0.844876               22314513.0
# 2  0.002993    0.000997                 0.830665               23745202.0
# 3  0.001996    0.000995                 0.759738               28676903.0
# 4  0.001992    0.000000                 0.867372               22483924.0
# 5  0.005985    0.003992                 0.906924               12252089.0
# 6  0.002970    0.000998                 0.853653               21839234.0
# 7  0.001995    0.000996                 0.783403               31923731.0
# 8  0.001991    0.000999                 0.839086               20864212.0
# 9  0.003004    0.000986                 0.829562               29947016.0

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, max_iter=1000000, random_state=42)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 2694.4202503369233

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 4522.746349144748

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.8607082904585118

# %%
final_model = Ridge(alpha=1, max_iter=1000000, random_state=42)
final_model.fit(X, y)
predictions = final_model.predict(X)
explained_variance_score(y, predictions)
# Out:
# 0.8476993709844195

# %%
from joblib import dump

# %%
dump(model, '../Models/health_insurance_model.joblib');
dump(converter, '../Models/health_insurance_converter.joblib');
dump(scaler, '../Models/health_insurance_scaler.joblib');

# %%
df.head()
